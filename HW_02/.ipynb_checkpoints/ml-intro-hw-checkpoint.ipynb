# %% [markdown]
# # SkillFactory
# ## Введение в ML, введение в sklearn

# %% [markdown]
# В этом задании мы с вами рассмотрим данные с конкурса [Задача предсказания отклика клиентов ОТП Банка](http://www.machinelearning.ru/wiki/index.php?title=%D0%97%D0%B0%D0%B4%D0%B0%D1%87%D0%B0_%D0%BF%D1%80%D0%B5%D0%B4%D1%81%D0%BA%D0%B0%D0%B7%D0%B0%D0%BD%D0%B8%D1%8F_%D0%BE%D1%82%D0%BA%D0%BB%D0%B8%D0%BA%D0%B0_%D0%BA%D0%BB%D0%B8%D0%B5%D0%BD%D1%82%D0%BE%D0%B2_%D0%9E%D0%A2%D0%9F_%D0%91%D0%B0%D0%BD%D0%BA%D0%B0_%28%D0%BA%D0%BE%D0%BD%D0%BA%D1%83%D1%80%D1%81%29)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# %% [markdown]
# ### Грузим данные

# %% [markdown]
# Считаем описание данных

# %%
df_descr = pd.read_csv('data/otp_description.csv', sep='\t', encoding='utf8')

# %%
df_descr
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                          AGE
# 2            SOCSTATUS_WORK_FL
# 3            SOCSTATUS_PENS_FL
# 4                       GENDER
# 5                  CHILD_TOTAL
# 6                   DEPENDANTS
# 7                    EDUCATION
# 8               MARITAL_STATUS
# 9                 GEN_INDUSTRY
# 10                   GEN_TITLE
# 11                ORG_TP_STATE
# 12             ORG_TP_FCAPITAL
# 13                     JOB_DIR
# 14               FAMILY_INCOME
# 15             PERSONAL_INCOME
# 16        REG_ADDRESS_PROVINCE
# 17       FACT_ADDRESS_PROVINCE
# 18     POSTAL_ADDRESS_PROVINCE
# 19                 TP_PROVINCE
# 20                   REGION_NM
# 21                 REG_FACT_FL
# 22                FACT_POST_FL
# 23                 REG_POST_FL
# 24            REG_FACT_POST_FL
# 25         REG_FACT_POST_TP_FL
# 26              FL_PRESENCE_FL
# 27                    OWN_AUTO
# 28                 AUTO_RUS_FL
# 29              HS_PRESENCE_FL
# 30             COT_PRESENCE_FL
# 31             GAR_PRESENCE_FL
# 32            LAND_PRESENCE_FL
# 33                      CREDIT
# 34                        TERM
# 35                 FST_PAYMENT
# 36              DL_DOCUMENT_FL
# 37             GPF_DOCUMENT_FL
# 38            FACT_LIVING_TERM
# 39                   WORK_TIME
# 40               FACT_PHONE_FL
# 41                REG_PHONE_FL
# 42                GEN_PHONE_FL
# 43              LOAN_NUM_TOTAL
# 44             LOAN_NUM_CLOSED
# 45               LOAN_NUM_PAYM
# 46                LOAN_DLQ_NUM
# 47                LOAN_MAX_DLQ
# 48            LOAN_AVG_DLQ_AMT
# 49            LOAN_MAX_DLQ_AMT
# 50  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1                                     возраст клиента
# 2   социальный статус клиента относительно работы ...
# 3   социальный статус клиента относительно пенсии ...
# 4                 пол клиента (1- женщины, 0-мужчины)
# 5                            количество детей клиента
# 6                       количество иждивенцев клиента
# 7                                         образование
# 8                                  семейное положение
# 9                              отрасль работы клиента
# 10                                          должность
# 11                       форма собственности компании
# 12                  отношение к иностранному капиталу
# 13          направление деятельности в нутри компании
# 14               семейный доход (несколько категорий)
# 15                    личный доход клиента (в рублях)
# 16                        область регистрации клиента
# 17            область фактического пребывания клиента
# 18                             почтовый адрес область
# 19  область торговой точки, где клиент брал послед...
# 20                                          регион РФ
# 21  адрес регистрации и адрес фактического пребыва...
# 22  адрес фактического пребывания клиента и его по...
# 23  адрес регистрации клиента и его почтовый адрес...
# 24  почтовый, фактический и адрес регистрации совп...
# 25  область регистрации, фактического пребывания, ...
# 26  наличие в собственности квартиры (1 - есть, 0 ...
# 27                кол-во автомобилей в собственности
# 28  наличие в собственности автомобиля российского...
# 29  наличие в собственности загородного дома (1 - ...
# 30  наличие в собственности котеджа (1 - есть, 0 -...
# 31  наличие в собственности гаража (1 - есть, 0 - ...
# 32  наличие в собственности земельного участка (1 ...
# 33        сумма последнего кредита клиента (в рублях)
# 34                                       срок кредита
# 35                    первоначальный взнос (в рублях)
# 36  в анкете клиент указал водительское удостовере...
# 37  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 38  количество месяцев проживания по месту фактиче...
# 39          время работы на текущем месте (в месяцах)
# 40  наличие в заявке телефона по фактическому мест...
# 41     наличие в заявке телефона по месту регистрации
# 42                 наличие в заявке рабочего телефона
# 43                            количество ссуд клиента
# 44                 количество погашенных ссуд клиента
# 45         количество платежей, которые сделал клиент
# 46          количество просрочек, допущенных клиентом
# 47  номер максимальной просрочки, допущенной клиентом
# 48                 средняя сумма просрочки (в рублях)
# 49            максимальная сумма просрочки (в рублях)
# 50  количество уже утилизированных карт ( если пус...

# %% [markdown]
# Считаем обучающую выборки и тестовую (которую мы как бы не видим)

# %%
df_train = pd.read_csv('data/otp_train.csv', sep='\t', encoding='utf8')

# %%
df_train.shape
# Out:
# (15223, 52)

# %%
df_test = pd.read_csv('data/otp_test.csv', sep='\t', encoding='utf8')

# %%
df_test.shape
# Out:
# (14910, 52)

# %%
df_train.head()
# Out:
#    AGREEMENT_RK  TARGET  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150       0   49                  1                  0       1
# 1      59910230       0   32                  1                  0       1
# 2      59910525       0   52                  1                  0       1
# 3      59910803       0   39                  1                  0       1
# 4      59911781       0   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#              ...             REG_PHONE_FL GEN_PHONE_FL LOAN_NUM_TOTAL  \
# 0            ...                        0            1              1
# 1            ...                        0            1              1
# 2            ...                        0            1              2
# 3            ...                        1            1              1
# 4            ...                        0            1              2
#
#   LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM LOAN_MAX_DLQ  LOAN_AVG_DLQ_AMT  \
# 0               1             6            2            1              1580
# 1               1             6            1            1              4020
# 2               1            11            0            0                 0
# 3               1             6            3            1  1589,92333333333
# 4               1            16            2            1           1152,15
#
#   LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED
# 0             1580                        NaN
# 1             4020                        NaN
# 2                0                        NaN
# 3             1590                        NaN
# 4             2230                        NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Объединим две выборки
#
# Так как пока мы пока не умеем работать sklearn  Pipeline, то для того, чтобы после предобработки столбцы в двух выборках находились на своих местах.
#
# Для того, чтобы в дальнейшем отделить их введем новый столбец "sample"

# %%
df_train.loc[:, 'sample'] = 'train'
df_test.loc[:, 'sample'] = 'test'

# %%
df = df_test.append(df_train).reset_index(drop=True)

# %%
df.shape
# Out:
# (30133, 53)

# %%
df.to_csv('df_cleared_out.csv', sep='\t')

# %% [markdown]
# ### Чуть-чуть посмотрим на данные

# %% [markdown]
# Посмотрим типы данных и их заполняемость

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null float64
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null float64
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null float64
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null float64
# LOAN_MAX_DLQ_AMT              30133 non-null float64
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(7), int64(32), object(14)
# memory usage: 12.2+ MB

# %% [markdown]
# Видим, что часть данных - object, скорее всего стоки.
#
#
# Давайте выведем эти значения для каждого столбца

# %%
for i in df_train.columns: # перебираем все столбцы
    if str(df_train[i].dtype) == 'object': # если тип столбца - object
        print('='*10)
        print(i) # выводим название столбца
        print(set(df_train[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n') # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Высшее', 'Среднее', 'Неоконченное высшее', 'Среднее специальное', 'Неполное среднее', 'Два и более высших образования', 'Ученая степень'}
#
#
# ==========
# MARITAL_STATUS
# {'Гражданский брак', 'Разведен(а)', 'Вдовец/Вдова', 'Не состоял в браке', 'Состою в браке'}
#
#
# ==========
# GEN_INDUSTRY
# {nan, 'Недвижимость', 'Маркетинг', 'Строительство', 'Салоны красоты и здоровья', 'Металлургия/Промышленность/Машиностроение', 'Энергетика', 'Информационные технологии', 'Юридические услуги/нотариальные услуги', 'Страхование', 'Развлечения/Искусство', 'Торговля', 'СМИ/Реклама/PR-агенства', 'Туризм', 'Образование', 'Коммунальное хоз-во/Дорожные службы', 'Ресторанный бизнес/Общественное питание', 'Сельское хозяйство', 'ЧОП/Детективная д-ть', 'Подбор персонала', 'Другие сферы', 'Наука', 'Химия/Парфюмерия/Фармацевтика', 'Здравоохранение', 'Сборочные производства', 'Государственная служба', 'Информационные услуги', 'Транспорт', 'Управляющая компания', 'Логистика', 'Банк/Финансы', 'Нефтегазовая промышленность'}
#
#
# ==========
# GEN_TITLE
# {nan, 'Руководитель высшего звена', 'Военнослужащий по контракту', 'Работник сферы услуг', 'Руководитель низшего звена', 'Индивидуальный предприниматель', 'Высококвалифиц. специалист', 'Специалист', 'Другое', 'Руководитель среднего звена', 'Служащий', 'Партнер', 'Рабочий'}
#
#
# ==========
# ORG_TP_STATE
# {nan, 'Государственная комп./учреж.', 'Индивидуальный предприниматель', 'Частная ком. с инос. капиталом', 'Некоммерческая организация', 'Частная компания'}
# {'Ивановская область', 'Калининградская область', 'Приморский край', 'Хабаровский край', 'Ростовская область', 'Кемеровская область', 'Агинский Бурятский АО', 'Тульская область', 'Магаданская область', 'Орловская область', 'Нижегородская область', 'Новосибирская область', 'Самарская область', 'Кировская область', 'Новгородская область', 'Карелия', 'Ярославская область', 'Красноярский край', 'Алтайский край', 'Саратовская область', 'Смоленская область', 'Дагестан', 'Воронежская область', 'Коми', 'Калмыкия', 'Северная Осетия', 'Владимирская область', 'Ханты-Мансийский АО', 'Удмуртия', 'Волгоградская область', 'Пензенская область', 'Еврейская АО', 'Чувашия', 'Мордовская республика', 'Пермская область', 'Рязанская область', 'Москва', 'Курганская область', 'Хакасия', 'Московская область', 'Сахалинская область', 'Омская область', 'Тверская область', 'Читинская область', 'Санкт-Петербург', 'Челябинская область', 'Ямало-Ненецкий АО', 'Марийская республика', 'Белгородская область', 'Псковская область', 'Томская область', 'Якутия', 'Башкирия', 'Оренбургская область', 'Астраханская область', 'Брянская область', 'Костромская область', 'Свердловская область', 'Бурятия', 'Вологодская область', 'Усть-Ордынский Бурятский АО', 'Амурская область', 'Мурманская область', 'Тамбовская область', 'Ставропольский край', 'Архангельская область', 'Карачаево-Черкесия', 'Эвенкийский АО', 'Ленинградская область', 'Татарстан', 'Курская область', 'Иркутская область', 'Краснодарский край', 'Калужская область', 'Липецкая область', 'Адыгея', 'Тюменская область', 'Кабардино-Балкария', 'Горный Алтай', 'Ульяновская область', 'Камчатская область'}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Ивановская область', 'Калининградская область', 'Приморский край', 'Хабаровский край', 'Ростовская область', 'Кемеровская область', 'Агинский Бурятский АО', 'Тульская область', 'Магаданская область', 'Орловская область', 'Нижегородская область', 'Новосибирская область', 'Самарская область', 'Кировская область', 'Новгородская область', 'Карелия', 'Ярославская область', 'Красноярский край', 'Алтайский край', 'Саратовская область', 'Смоленская область', 'Дагестан', 'Воронежская область', 'Коми', 'Калмыкия', 'Северная Осетия', 'Владимирская область', 'Ханты-Мансийский АО', 'Удмуртия', 'Волгоградская область', 'Пензенская область', 'Еврейская АО', 'Чувашия', 'Мордовская республика', 'Пермская область', 'Рязанская область', 'Москва', 'Курганская область', 'Хакасия', 'Московская область', 'Сахалинская область', 'Омская область', 'Тверская область', 'Читинская область', 'Санкт-Петербург', 'Челябинская область', 'Ямало-Ненецкий АО', 'Марийская республика', 'Белгородская область', 'Псковская область', 'Томская область', 'Якутия', 'Башкирия', 'Оренбургская область', 'Астраханская область', 'Брянская область', 'Костромская область', 'Свердловская область', 'Бурятия', 'Вологодская область', 'Усть-Ордынский Бурятский АО', 'Амурская область', 'Мурманская область', 'Тамбовская область', 'Ставропольский край', 'Архангельская область', 'Карачаево-Черкесия', 'Эвенкийский АО', 'Ленинградская область', 'Татарстан', 'Курская область', 'Иркутская область', 'Краснодарский край', 'Калужская область', 'Липецкая область', 'Адыгея', 'Тюменская область', 'Кабардино-Балкария', 'Горный Алтай', 'Ульяновская область', 'Камчатская область'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Ивановская область', 'Калининградская область', 'Приморский край', 'Хабаровский край', 'Ростовская область', 'Кемеровская область', 'Агинский Бурятский АО', 'Тульская область', 'Магаданская область', 'Орловская область', 'Нижегородская область', 'Новосибирская область', 'Самарская область', 'Кировская область', 'Новгородская область', 'Карелия', 'Ярославская область', 'Красноярский край', 'Алтайский край', 'Саратовская область', 'Смоленская область', 'Воронежская область', 'Коми', 'Калмыкия', 'Северная Осетия', 'Владимирская область', 'Ханты-Мансийский АО', 'Удмуртия', 'Волгоградская область', 'Пензенская область', 'Еврейская АО', 'Чувашия', 'Мордовская республика', 'Пермская область', 'Рязанская область', 'Москва', 'Курганская область', 'Хакасия', 'Московская область', 'Сахалинская область', 'Омская область', 'Тверская область', 'Читинская область', 'Санкт-Петербург', 'Челябинская область', 'Ямало-Ненецкий АО', 'Марийская республика', 'Белгородская область', 'Псковская область', 'Томская область', 'Якутия', 'Башкирия', 'Оренбургская область', 'Астраханская область', 'Брянская область', 'Костромская область', 'Свердловская область', 'Бурятия', 'Вологодская область', 'Усть-Ордынский Бурятский АО', 'Амурская область', 'Мурманская область', 'Тамбовская область', 'Ставропольский край', 'Архангельская область', 'Карачаево-Черкесия', 'Эвенкийский АО', 'Ленинградская область', 'Татарстан', 'Курская область', 'Иркутская область', 'Краснодарский край', 'Калужская область', 'Липецкая область', 'Адыгея', 'Тюменская область', 'Кабардино-Балкария', 'Горный Алтай', 'Ульяновская область', 'Камчатская область'}
#
#
# ==========
# TP_PROVINCE
# {'Ивановская область', nan, 'Приморский край', 'Хабаровский край', 'Калининградская область', 'Ростовская область', 'Кемеровская область', 'Тульская область', 'Магаданская область', 'Орловская область', 'Нижегородская область', 'Новосибирская область', 'Самарская область', 'Кировская область', 'Новгородская область', 'Карелия', 'Ярославская область', 'Красноярский край', 'Алтайский край', 'Саратовская область', 'Смоленская область', 'Воронежская область', 'Коми', 'Владимирская область', 'Ханты-Мансийский АО', 'Удмуртия', 'Волгоградская область', 'Пензенская область', 'Еврейская АО', 'Чувашия', 'Мордовская республика', 'Пермская область', 'Рязанская область', 'Москва', 'Курганская область', 'Сахалинская область', 'Омская область', 'Тверская область', 'Читинская область', 'Санкт-Петербург', 'Челябинская область', 'Марийская республика', 'Белгородская область', 'Псковская область', 'Томская область', 'Якутия', 'Башкирия', 'Оренбургская область', 'Астраханская область', 'Брянская область', 'Костромская область', 'Свердловская область', 'Бурятия', 'Вологодская область', 'Амурская область', 'Мурманская область', 'Тамбовская область', 'Ставропольский край', 'Архангельская область', 'Курская область', 'Татарстан', 'Иркутская область', 'Краснодарский край', 'Калужская область', 'Липецкая область', 'Адыгея', 'Тюменская область', 'Кабардино-Балкария', 'Горный Алтай', 'Ульяновская область', 'Камчатская область'}
#
#
# ==========
# REGION_NM
# {nan, 'ВОСТОЧНО-СИБИРСКИЙ', 'ЦЕНТРАЛЬНЫЙ 1', 'ПОВОЛЖСКИЙ', 'ЦЕНТРАЛЬНЫЙ 2', 'ЮЖНЫЙ', 'ДАЛЬНЕВОСТОЧНЫЙ', 'ПРИВОЛЖСКИЙ', 'ЦЕНТРАЛЬНЫЙ ОФИС', 'УРАЛЬСКИЙ', 'ЗАПАДНО-СИБИРСКИЙ', 'СЕВЕРО-ЗАПАДНЫЙ'}
', '2441,4', '2598,9', '1931,44', '1410', '2569,05', '937,6', '730', '1819,26', '1930,47', '1870,69', '1489,13', '1127,76', '2880', '2425', '3230', '2160', '600,93', '1901,3', '1086,57', '1599,9', '798,53', '2980', '3530', '870', '850', '658,42', '1845,5', '1508,79', '1450,22', '892,95', '1371,86', '613,21', '2570', '663,05', '1324,5', '910', '1426,72', '3420', '2900', '470', '2830', '2365,47', '796,59', '826,77', '776,6', '3700', '1302,38', '560', '946,49', '3390', '2940', '599,19', '1663,27', '1249,61', '1288,7', '862,5', '1094', '1010', '2084,32', '4508,2', '1459,99', '830,53', '497,62', '2580', '4940', '2702,4', '810', '2699,88', '3240', '2970', '0,71', '2679,82', '2320', '1460', '5075,99', '1330', '682', '3285,74', '1670', '2960', '4640', '478,13', '2989,98', '2263,2', '702,23', '5430', '2110', '6133,41', '830,7', '3770', '7340', '1402,43', '1672,88', '1319,56', '2200', '687,11', '3610', '940', '6080', '1312,44', '490', '2590,15', '821,93', '1 ...
#
#
# ==========
# sample
# {'train'}

# %%
for i in df.columns: # перебираем все столбцы
    if str(df[i].dtype) == 'object': # если тип столбца - object
        print('='*10)
        print(i) # выводим название столбца
        print(set(df[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print('\n') # выводим пустую строку
# Out:
# ==========
# EDUCATION
# {'Высшее', 'Среднее', 'Неоконченное высшее', 'Среднее специальное', 'Неполное среднее', 'Два и более высших образования', 'Ученая степень'}
#
#
# ==========
# MARITAL_STATUS
# {'Гражданский брак', 'Разведен(а)', 'Вдовец/Вдова', 'Не состоял в браке', 'Состою в браке'}
#
#
# ==========
# GEN_INDUSTRY
# {nan, 'Недвижимость', 'Маркетинг', 'Строительство', 'Салоны красоты и здоровья', 'Металлургия/Промышленность/Машиностроение', 'Энергетика', 'Информационные технологии', 'Юридические услуги/нотариальные услуги', 'Страхование', 'Развлечения/Искусство', 'Торговля', 'СМИ/Реклама/PR-агенства', 'Туризм', 'Образование', 'Коммунальное хоз-во/Дорожные службы', 'Ресторанный бизнес/Общественное питание', 'Сельское хозяйство', 'ЧОП/Детективная д-ть', 'Подбор персонала', 'Другие сферы', 'Наука', 'Химия/Парфюмерия/Фармацевтика', 'Здравоохранение', 'Сборочные производства', 'Государственная служба', 'Информационные услуги', 'Транспорт', 'Управляющая компания', 'Логистика', 'Банк/Финансы', 'Нефтегазовая промышленность'}
#
#
# ==========
# GEN_TITLE
# {nan, 'Руководитель высшего звена', 'Военнослужащий по контракту', 'Работник сферы услуг', 'Руководитель низшего звена', 'Индивидуальный предприниматель', 'Высококвалифиц. специалист', 'Специалист', 'Другое', 'Руководитель среднего звена', 'Служащий', 'Партнер', 'Рабочий'}
#
#
# ==========
# ORG_TP_STATE
# {nan, 'Государственная комп./учреж.', 'Индивидуальный предприниматель', 'Частная ком. с инос. капиталом', 'Некоммерческая организация', 'Частная компания'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {nan, 'С участием', 'Без участия'}
#
#
# ==========
# JOB_DIR
# {nan, 'Адм-хоз. и трансп. службы', 'Бухгалтерия, финансы, планир.', 'Участие в основ. деятельности', 'Реклама и маркетинг', 'Юридическая служба', 'Вспомогательный техперсонал', 'Пр-техн. обесп. и телеком.', 'Кадровая служба и секретариат', 'Снабжение и сбыт', 'Служба безопасности'}
#
#
# ==========
# FAMILY_INCOME
# {'свыше 50000 руб.', 'от 20000 до 50000 руб.', 'от 10000 до 20000 руб.', 'до 5000 руб.', 'от 5000 до 10000 руб.'}
#
#
# ==========
# REG_ADDRESS_PROVINCE
# {'Ивановская область', 'Калининградская область', 'Приморский край', 'Хабаровский край', 'Ростовская область', 'Кемеровская область', 'Агинский Бурятский АО', 'Тульская область', 'Магаданская область', 'Орловская область', 'Нижегородская область', 'Новосибирская область', 'Кировская область', 'Новгородская область', 'Самарская область', 'Красноярский край', 'Алтайский край', 'Ярославская область', 'Карелия', 'Смоленская область', 'Саратовская область', 'Дагестан', 'Воронежская область', 'Коми', 'Калмыкия', 'Коми-Пермяцкий АО', 'Северная Осетия', 'Владимирская область', 'Ханты-Мансийский АО', 'Удмуртия', 'Волгоградская область', 'Пензенская область', 'Еврейская АО', 'Чувашия', 'Мордовская республика', 'Пермская область', 'Рязанская область', 'Москва', 'Курганская область', 'Хакасия', 'Московская область', 'Сахалинская область', 'Омская область', 'Тверская область', 'Читинская область', 'Санкт-Петербург', 'Челябинская область', 'Ямало-Ненецкий АО', 'Марийская республика', 'Томская область', 'Псковская область', 'Белгородская область', 'Якутия', 'Астраханская область', 'Оренбургская область', 'Брянская область', 'Башкирия', 'Костромская область', 'Свердловская область', 'Бурятия', 'Вологодская область', 'Усть-Ордынский Бурятский АО', 'Амурская область', 'Мурманская область', 'Тамбовская область', 'Ставропольский край', 'Архангельская область', 'Карачаево-Черкесия', 'Эвенкийский АО', 'Курская область', 'Татарстан', 'Ленинградская область', 'Иркутская область', 'Краснодарский край', 'Липецкая область', 'Калужская область', 'Адыгея', 'Тюменская область', 'Кабардино-Балкария', 'Горный Алтай', 'Ульяновская область', 'Камчатская область'}
#
#
# ==========
# FACT_ADDRESS_PROVINCE
# {'Ивановская область', 'Калининградская область', 'Приморский край', 'Хабаровский край', 'Ростовская область', 'Кемеровская область', 'Агинский Бурятский АО', 'Тульская область', 'Магаданская область', 'Орловская область', 'Нижегородская область', 'Новосибирская область', 'Кировская область', 'Новгородская область', 'Самарская область', 'Красноярский край', 'Алтайский край', 'Ярославская область', 'Карелия', 'Смоленская область', 'Саратовская область', 'Дагестан', 'Воронежская область', 'Коми', 'Калмыкия', 'Коми-Пермяцкий АО', 'Северная Осетия', 'Владимирская область', 'Ханты-Мансийский АО', 'Удмуртия', 'Волгоградская область', 'Пензенская область', 'Еврейская АО', 'Чувашия', 'Мордовская республика', 'Пермская область', 'Рязанская область', 'Москва', 'Курганская область', 'Хакасия', 'Московская область', 'Сахалинская область', 'Омская область', 'Тверская область', 'Читинская область', 'Санкт-Петербург', 'Челябинская область', 'Ямало-Ненецкий АО', 'Марийская республика', 'Томская область', 'Псковская область', 'Белгородская область', 'Якутия', 'Астраханская область', 'Оренбургская область', 'Брянская область', 'Башкирия', 'Костромская область', 'Свердловская область', 'Бурятия', 'Вологодская область', 'Усть-Ордынский Бурятский АО', 'Амурская область', 'Мурманская область', 'Тамбовская область', 'Ставропольский край', 'Архангельская область', 'Карачаево-Черкесия', 'Эвенкийский АО', 'Курская область', 'Татарстан', 'Ленинградская область', 'Иркутская область', 'Краснодарский край', 'Липецкая область', 'Калужская область', 'Адыгея', 'Чечня', 'Тюменская область', 'Кабардино-Балкария', 'Горный Алтай', 'Ульяновская область', 'Камчатская область'}
#
#
# ==========
# POSTAL_ADDRESS_PROVINCE
# {'Ивановская область', 'Калининградская область', 'Приморский край', 'Хабаровский край', 'Ростовская область', 'Кемеровская область', 'Агинский Бурятский АО', 'Тульская область', 'Магаданская область', 'Орловская область', 'Нижегородская область', 'Новосибирская область', 'Кировская область', 'Новгородская область', 'Самарская область', 'Красноярский край', 'Алтайский край', 'Ярославская область', 'Карелия', 'Смоленская область', 'Саратовская область', 'Дагестан', 'Воронежская область', 'Коми', 'Калмыкия', 'Коми-Пермяцкий АО', 'Северная Осетия', 'Владимирская область', 'Ханты-Мансийский АО', 'Удмуртия', 'Волгоградская область', 'Пензенская область', 'Еврейская АО', 'Чувашия', 'Мордовская республика', 'Пермская область', 'Рязанская область', 'Москва', 'Курганская область', 'Хакасия', 'Московская область', 'Сахалинская область', 'Омская область', 'Тверская область', 'Читинская область', 'Санкт-Петербург', 'Челябинская область', 'Ямало-Ненецкий АО', 'Марийская республика', 'Томская область', 'Псковская область', 'Белгородская область', 'Якутия', 'Астраханская область', 'Оренбургская область', 'Брянская область', 'Башкирия', 'Костромская область', 'Свердловская область', 'Бурятия', 'Вологодская область', 'Усть-Ордынский Бурятский АО', 'Амурская область', 'Мурманская область', 'Тамбовская область', 'Ставропольский край', 'Архангельская область', 'Карачаево-Черкесия', 'Эвенкийский АО', 'Курская область', 'Татарстан', 'Ленинградская область', 'Иркутская область', 'Краснодарский край', 'Липецкая область', 'Калужская область', 'Адыгея', 'Тюменская область', 'Кабардино-Балкария', 'Горный Алтай', 'Ульяновская область', 'Камчатская область'}
#
#
# ==========
# TP_PROVINCE
# {'Ивановская область', nan, 'Калининградская область', 'Хабаровский край', 'Приморский край', 'Ростовская область', 'Кемеровская область', 'Тульская область', 'Магаданская область', 'Орловская область', 'Нижегородская область', 'Новосибирская область', 'Кировская область', 'Новгородская область', 'Самарская область', 'Красноярский край', 'Алтайский край', 'Ярославская область', 'Карелия', 'Смоленская область', 'Саратовская область', 'Воронежская область', 'Коми', 'Владимирская область', 'Ханты-Мансийский АО', 'Удмуртия', 'Волгоградская область', 'Пензенская область', 'Еврейская АО', 'Чувашия', 'Мордовская республика', 'Пермская область', 'Рязанская область', 'Москва', 'Курганская область', 'Сахалинская область', 'Омская область', 'Тверская область', 'Читинская область', 'Санкт-Петербург', 'Челябинская область', 'Марийская республика', 'Томская область', 'Псковская область', 'Белгородская область', 'Якутия', 'Астраханская область', 'Оренбургская область', 'Брянская область', 'Башкирия', 'Костромская область', 'Свердловская область', 'Бурятия', 'Вологодская область', 'Амурская область', 'Мурманская область', 'Тамбовская область', 'Ставропольский край', 'Архангельская область', 'Курская область', 'Татарстан', 'Иркутская область', 'Краснодарский край', 'Липецкая область', 'Калужская область', 'Адыгея', 'Тюменская область', 'Кабардино-Балкария', 'Горный Алтай', 'Ульяновская область', 'Камчатская область'}
#
#
# ==========
# REGION_NM
# {nan, 'ВОСТОЧНО-СИБИРСКИЙ', 'ЦЕНТРАЛЬНЫЙ 1', 'ПОВОЛЖСКИЙ', 'ЦЕНТРАЛЬНЫЙ 2', 'ПРИВОЛЖСКИЙ', 'ДАЛЬНЕВОСТОЧНЫЙ', 'ЮЖНЫЙ', 'ЦЕНТРАЛЬНЫЙ ОФИС', 'УРАЛЬСКИЙ', 'ЗАПАДНО-СИБИРСКИЙ', 'СЕВЕРО-ЗАПАДНЫЙ'}
#
#
# ==========
# sample
# {'train', 'test'}

# %% [markdown]
# Mожно заметить что некоторые переменные, которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа, но по какой-то причине были распознаны как строки
#
# Причина же что использовалась запятая для разделения не целой части числа..

# %% [markdown]
# Перекодировать их можно например так:

# %%
df['PERSONAL_INCOME'] = df['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')

# %%
df['CREDIT'] = df['CREDIT'].map(lambda x: x.replace(',', '.')).astype('float')

# %%
df['FST_PAYMENT'] = df['FST_PAYMENT'].map(lambda x: x.replace(',', '.')).astype('float')

# %%
df['LOAN_AVG_DLQ_AMT'] = df['LOAN_AVG_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')

# %%
df['LOAN_MAX_DLQ_AMT'] = df['LOAN_MAX_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')

# %% [markdown]
# Такой эффект наблюдается в столбцах `PERSONAL_INCOME`, `CREDIT`, `FST_PAYMENT`, `LOAN_AVG_DLQ_AMT`, `LOAN_MAX_DLQ_AMT`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 53 columns):
# AGREEMENT_RK                  30133 non-null int64
# TARGET                        30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null float64
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null float64
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null float64
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null float64
# LOAN_MAX_DLQ_AMT              30133 non-null float64
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# sample                        30133 non-null object
# dtypes: float64(7), int64(32), object(14)
# memory usage: 12.2+ MB

# %% [markdown]
# ### Теперь ваше небольшое исследование

# %% [markdown]
# #### Задание 1. Есть ли пропуски в данных? Что с ними сделать?
#
# (единственного верного ответа нет - аргументируйте)

# %% [markdown]
# Пропуски есть
#
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# TP_PROVINCE                   29543 non-null object
# WORK_TIME                     27416 non-null float64
#
# содержат меньше данных чем итоговая выборка = 30133 строк
#
# ==========
# GEN_INDUSTRY
# {**nan**, 'Недвижимость', 'Маркетинг', 'Строительство', 'Салоны красоты и здоровья', 'Металлургия/Промышленность/Машиностроение', 'Энергетика', 'Информационные технологии', 'Юридические услуги/нотариальные услуги', 'Страхование', 'Развлечения/Искусство', 'Торговля', 'СМИ/Реклама/PR-агенства', 'Туризм', 'Образование', 'Коммунальное хоз-во/Дорожные службы', 'Ресторанный бизнес/Общественное питание', 'Сельское хозяйство', 'ЧОП/Детективная д-ть', 'Подбор персонала', 'Другие сферы', 'Наука', 'Химия/Парфюмерия/Фармацевтика', 'Здравоохранение', 'Сборочные производства', 'Государственная служба', 'Информационные услуги', 'Транспорт', 'Управляющая компания', 'Логистика', 'Банк/Финансы', 'Нефтегазовая промышленность'}
#
#
# ==========
# GEN_TITLE
# {**nan**, 'Руководитель высшего звена', 'Военнослужащий по контракту', 'Работник сферы услуг', 'Руководитель низшего звена', 'Индивидуальный предприниматель', 'Высококвалифиц. специалист', 'Специалист', 'Другое', 'Руководитель среднего звена', 'Служащий', 'Партнер', 'Рабочий'}
#
#
# ==========
# ORG_TP_STATE
# {**nan**, 'Государственная комп./учреж.', 'Индивидуальный предприниматель', 'Частная ком. с инос. капиталом', 'Некоммерческая организация', 'Частная компания'}
#
#
# ==========
# ORG_TP_FCAPITAL
# {**nan**, 'С участием', 'Без участия'}
#
#
# ==========
# JOB_DIR
# {**nan**, 'Адм-хоз. и трансп. службы', 'Бухгалтерия, финансы, планир.', 'Участие в основ. деятельности', 'Реклама и маркетинг', 'Юридическая служба', 'Вспомогательный техперсонал', 'Пр-техн. обесп. и телеком.', 'Кадровая служба и секретариат', 'Снабжение и сбыт', 'Служба безопасности'}

# %% [markdown]
# #### Задание 2. Есть ли категориальные признаки? Что с ними делать?

# %% [markdown]
# Категориальные признаки присутствуют, необходимо провести их кодирование, одним из спсообов. ( В лекции предложен способ dummy-кодирования)

# %% [markdown]
# #### Задание 3. Фунция предобработки

# %% [markdown]
# Напишите функцию, которая бы
#
# * Удаляло идентификатор `AGREEMENT_RK`
# * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT
# * Что-то делала с пропусками
# * Кодировала категориальные признаки
#
# В результате, ваш датафрейм должен содержать только числа и не содержать пропусков!

# %%
def preproc_data(df_input, listNumCol, listMapValue):
    df_output = df_input.copy()
 # * Удаляло идентификатор `AGREEMENT_RK`
    df_output = df_output.drop(['AGREEMENT_RK'], axis=1)

 # * Избавлялась от проблем с '.' и ',' в стобцах PERSONAL_INCOME, CREDIT, FST_PAYMENT, LOAN_AVG_DLQ_AMT, LOAN_MAX_DLQ_AMT    
    # преоборазуем строки из переданного в параметрах списка колонок которые мы приняли за цифровые значения
    for colName in listNumCol:
        df_output[colName] = df_output[colName].map(lambda x: x.replace(',', '.')).astype('float')  
      
 #  Что-то делала с пропусками    
    # заполнение пропусков заранее определенных полей заданными условиями значениямит 
    for iMapValue in listMapValue:
        if colName in iMapValue[0]:
            df_output[iMapValue] = df_output[iMapValue].fillna( value = iMapValue [1] )

    df_output = df_output.dropna(axis=0)
    
    # заполнение пропусков значением "Неизвестный" для строковых переменных, т.к. они полностью разнородные 
    # и их восстановление фактически потребует отдельных моделей. Поэтому ввел одну общую характеристику
    # в дальнейшем отказался от этой стратегии заменил её на удаление записей с неизвестными значениями
    for i in df_output.columns: # перебираем все столбцы
        if str(df_output[i].dtype) == 'object': # если тип столбца - object
            df_output[i] = df_output[i].fillna( value='UNKNOWN')

        if ((str(df_output[i].dtype) == 'float64') and (df_output[i].min() > 0)) : # если тип столбца - object
            df_output[i] = df_output[i].fillna( value=-1 )

    
            
 # Кодировала категориальные признаки  
    df_output = pd.get_dummies(df_output)
    
    return df_output

# %%
def inline_preproc_data(df_input):
    listNumCol = ['PERSONAL_INCOME','CREDIT', 'FST_PAYMENT', 'LOAN_AVG_DLQ_AMT', 'LOAN_MAX_DLQ_AMT']
    listMapValue = [
            [['PREVIOUS_CARD_NUM_UTILIZED'], 0],
        ]

    dfOut = preproc_data ( df, listNumCol, listMapValue )
    return dfOut

# %%
df_preproc = df.pipe(inline_preproc_data)

df_train_preproc = df_preproc.query('sample_train == "1"').drop(['sample_train', 'sample_test'], axis=1)
df_test_preproc = df_preproc.query('sample_test == "1"').drop(['sample_train', 'sample_test'], axis=1)
df_preproc = df_preproc.drop(['sample_train', 'sample_test'], axis=1)

# %%
## поглядим что получилось

# df_preproc.to_csv('df_preproc.csv', sep='\t')
# df_train_preproc.to_csv('df_train_preproc.csv', sep='\t')
# df_test_preproc.to_csv('df_test_preproc.csv', sep='\t')

# %% [markdown]
# #### Задание 4. Отделите целевую переменную и остальные признаки
#
# Должно получится:
# * 2 матрицы: X и X_test
# * 2 вектора: y и y_test

# %%
X = df_train_preproc.copy()
y = df_train_preproc['TARGET']
X = X.drop(['TARGET'], axis=1)

X_test = df_test_preproc.copy()
y_test = df_test_preproc['TARGET']
X_test = X_test.drop(['TARGET'], axis=1)

# %% [markdown]
# #### Задание 5. Обучение и оценка качества разных моделей

# %%
from sklearn.cross_validation import train_test_split
# test_size=0.3, random_state=42
## Your Code Here


X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
#     fit, 
#     predict, 
#     predict_proba
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc_fit = dtc.fit(X_train2, y_train2)
dtc_predict = dtc.predict(X_test2)
dtc_predict_proba = dtc.predict_proba(X_test2)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()
rfc_fit = rfc.fit(X_train2, y_train2)
rfc_predict = rfc.predict(X_test2)
rfc_predict_proba = rfc.predict_proba(X_test2)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()
lr_fit = lr.fit(X_train2, y_train2)
lr_predict = lr.predict(X_test2)
lr_predict_proba = lr.predict_proba(X_test2)

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
print ('***** DecisionTreeClassifier ******')
print('precision', precision_score(y_test2, dtc_predict))
print('recall', recall_score(y_test2, dtc_predict))
print('accuracy', accuracy_score(y_test2, dtc_predict))
print('f1', f1_score(y_test2, dtc_predict))
print ('***** RandomForestClassifier ******')
print('precision', precision_score(y_test2, rfc_predict))
print('recall', recall_score(y_test2, rfc_predict))
print('accuracy', accuracy_score(y_test2, rfc_predict))
print('f1', f1_score(y_test2, rfc_predict))
print ('***** LogisticRegression ******')
print('precision', precision_score(y_test2, lr_predict))
print('recall', recall_score(y_test2, lr_predict))
print('accuracy', accuracy_score(y_test2, lr_predict))
print('f1', f1_score(y_test2, lr_predict))
# Out:
# ***** DecisionTreeClassifier ******
# precision 0.4375
# recall 0.28
# accuracy 0.6707317073170732
# f1 0.34146341463414637
# ***** RandomForestClassifier ******
# precision 0.3333333333333333
# recall 0.04
# accuracy 0.6829268292682927
# f1 0.07142857142857142
# ***** LogisticRegression ******
# precision 0.35714285714285715
# recall 0.2
# accuracy 0.6463414634146342
# f1 0.25641025641025644

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально посмотреть)

## Your Code Here

# %%
# Потроить roc-кривые всех можелей на одном графике
# Вывести roc_auc каждой моделе

# %matplotlib inline
from matplotlib import pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve
dtc_fpr, dtc_tpr, dtc_thresholds = roc_curve(y_test2, dtc_predict)
rfc_fpr, rfc_tpr, rfc_thresholds = roc_curve(y_test2, rfc_predict)
lr_fpr, lr_tpr, lr_thresholds = roc_curve(y_test2, lr_predict)
plt.figure(figsize=(5, 5))
plt.plot(dtc_fpr, dtc_tpr)
plt.plot(rfc_fpr, rfc_tpr)
plt.plot(lr_fpr, lr_tpr)
plt.ylabel('tpr')
plt.xlabel('fpr')
plt.grid(True)
plt.title('ROC curve')
plt.xlim((-0.01, 1.01))
plt.ylim((-0.01, 1.01))
# Out:
# (-0.01, 1.01)

# %%
print ( "roc_auc_dtc", roc_auc_score(y_test2, dtc_predict) )
print ( "roc_auc_rfc", roc_auc_score(y_test2, rfc_predict) )
print ( "roc_auc_lr", roc_auc_score(y_test2, lr_predict) )
# Out:
# roc_auc_dtc 0.5610526315789474
# roc_auc_rfc 0.5024561403508772
# roc_auc_lr 0.5210526315789473

# %%
from sklearn.cross_validation import cross_val_score
from sklearn.model_selection import StratifiedKFold
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=123)

df = pd.DataFrame(columns=['roc_auc_dtc', 'roc_auc_rfc', 'roc_auc_lr'])

for train_index, test_index in skf.split(X, y):
    f_train_X, f_test_X = X.iloc[train_index], X.iloc[test_index]
    f_train_y, f_test_y = y.iloc[train_index], y.iloc[test_index]    

    kf_dtc = DecisionTreeClassifier()    
    kf_dtc_fit = kf_dtc.fit(f_train_X, f_train_y)
    kf_dtc_predict = kf_dtc.predict(f_test_X)
    roc_auc_dtc = roc_auc_score(f_test_y, kf_dtc_predict)
    print ( "roc_auc_dtc", roc_auc_dtc )    
    
    kf_rfc = RandomForestClassifier()
    kf_rfc_fit = kf_rfc.fit(f_train_X, f_train_y)
    kf_rfc_predict = kf_rfc.predict(f_test_X)
    roc_auc_rfc = roc_auc_score(f_test_y, kf_rfc_predict) 
    print ( "roc_auc_rfc", roc_auc_rfc )
    
    kf_lr = LogisticRegression()    
    kf_lr_fit = lr.fit(f_train_X, f_train_y)
    kf_lr_predict = lr.predict(f_test_X)
    roc_auc_lr = roc_auc_score(f_test_y, kf_lr_predict) 
    print ( "roc_auc_lr", roc_auc_lr )   
    
    df = df.append({
            'roc_auc_dtc': roc_auc_dtc
        , 'roc_auc_rfc': roc_auc_rfc
        , 'roc_auc_lr': roc_auc_lr}
        , ignore_index=True)
    
    #print("TRAIN:", train_index, "TEST:", test_index)
    #Xkf_train, Xkf_test = X[train_index], X[test_index]
    #ykf_train, ykf_test = y[train_index], y[test_index]
# Out:
# roc_auc_dtc 0.587719298245614
# roc_auc_rfc 0.42105263157894735
# roc_auc_lr 0.6169590643274854
# roc_auc_dtc 0.42690058479532167
# roc_auc_rfc 0.4736842105263158
# roc_auc_lr 0.5321637426900585
# roc_auc_dtc 0.4005847953216375
# roc_auc_rfc 0.5
# roc_auc_lr 0.5614035087719298
# roc_auc_dtc 0.5116959064327485
# roc_auc_rfc 0.5029239766081872
# roc_auc_lr 0.3976608187134503
# roc_auc_dtc 0.5032894736842105
# roc_auc_rfc 0.5361842105263158
# roc_auc_lr 0.6348684210526316
# roc_auc_dtc 0.3782894736842105
# roc_auc_rfc 0.42105263157894735
# roc_auc_lr 0.368421052631579
# roc_auc_dtc 0.4144736842105263
# roc_auc_rfc 0.5361842105263158
# roc_auc_lr 0.493421052631579
# roc_auc_dtc 0.6041666666666667
# roc_auc_rfc 0.4791666666666667
# roc_auc_lr 0.5347222222222222
# roc_auc_dtc 0.4861111111111111
# roc_auc_rfc 0.6319444444444444
# roc_auc_lr 0.5069444444444444
# roc_auc_dtc 0.4861111111111111
# roc_auc_rfc 0.5
# roc_auc_lr 0.5069444444444444
# <bound method DataFrame.mean of    roc_auc_dtc  roc_auc_rfc  roc_auc_lr
# 0     0.587719     0.421053    0.616959
# 1     0.426901     0.473684    0.532164
# 2     0.400585     0.500000    0.561404
# 3     0.511696     0.502924    0.397661
# 4     0.503289     0.536184    0.634868
# 5     0.378289     0.421053    0.368421
# 6     0.414474     0.536184    0.493421
# 7     0.604167     0.479167    0.534722
# 8     0.486111     0.631944    0.506944
# 9     0.486111     0.500000    0.506944>

# %%
df.mean()
# Out:
# roc_auc_dtc    0.479934
# roc_auc_rfc    0.500219
# roc_auc_lr     0.515351
# dtype: float64

# %%
# Взять лучшую модель и сделать predict (с вероятностями (!!!)) для test выборки
lr_predict_probaTest = lr.predict_proba(X_test)
lr_predict_probaTest
# Out:
# array([[0.4293411 , 0.5706589 ],
#        [0.66337203, 0.33662797],
#        [0.9489505 , 0.0510495 ],
#        [0.79578385, 0.20421615],
#        [0.91192044, 0.08807956],
#        [0.60535339, 0.39464661],
#        [0.11523542, 0.88476458],
#        [0.20371244, 0.79628756],
#        [0.92739936, 0.07260064],
#        [0.53002324, 0.46997676],
#        [0.29502042, 0.70497958],
#        [0.19368724, 0.80631276],
#        [0.78595359, 0.21404641],
#        [0.3526628 , 0.6473372 ],
#        [0.8271179 , 0.1728821 ],
#        [0.64715637, 0.35284363],
#        [0.75739625, 0.24260375],
#        [0.27518577, 0.72481423],
#        [0.6132608 , 0.3867392 ],
#        [0.52492778, 0.47507222],
#        [0.46513578, 0.53486422],
#        [0.82381378, 0.17618622],
#        [0.86014612, 0.13985388],
#        [0.92820777, 0.07179223],
#        [0.22840688, 0.77159312],
#        [0.98000479, 0.01999521],
#        [0.50708104, 0.49291896],
#        [0.85798331, 0.14201669],
#        [0.94232665, 0.05767335],
#        [0.96722617, 0.03277383],
#        [0.78181723, 0.21818277],
#        [0.52318612, 0.47681388],
#        [0.97423548, 0.02576452],
#        [0.85622178, 0.14377822],
#        [0.79047547, 0.20952453],
#        [0.35957406, 0.64042594],
#        [0.78094222, 0.21905778],
#        [0.92133307, 0.07866693],
#        [0.61019046, 0.38980954],
#        [0.91280044, 0.08719956],
#        [0.67575334, 0.32424666],
#        [0.73291902, 0.26708098],
#        [0.93220205, 0.06779795],
#        [0.64566705, 0.35433295],
#        [0.90053048, 0.09946952],
#        [0.8067352 , 0.1932648 ],
#        [0.7200644 , 0.2799356 ],
#        [0.896541  , 0.103459  ],
#        [0.44084315, 0.55915685],
#        [0.85219635, 0.14780365],
#        [0.48114865, 0.51885135],
#        [0.79587124, 0.20412876],
#        [0.27423021, 0.72576979],
#        [0.78938362, 0.21061638],
#        [0.94058519, 0.05941481],
#        [0.95000396, 0.04999604],
#        [0.93220029, 0.06779971],
#        [0.56583388, 0.43416612],
#        [0.62989989, 0.37010011],
#        [0.91581169, 0.08418831],
#        [0.96726394, 0.03273606],
#        [0.97214168, 0.02785832],
#        [0.32081467, 0.67918533],
#        [0.83146833, 0.16853167],
#        [0.47369546, 0.52630454],
#        [0.12724343, 0.87275657],
#        [0.19888466, 0.80111534],
#        [0.90702566, 0.09297434],
#        [0.57295362, 0.42704638],
#        [0.78057294, 0.21942706],
#        [0.77513951, 0.22486049],
#        [0.87833212, 0.12166788],
#        [0.81328087, 0.18671913],
#        [0.40923855, 0.59076145],
#        [0.93159992, 0.06840008],
#        [0.64855688, 0.35144312],
#        [0.73922471, 0.26077529],
#        [0.61781574, 0.38218426],
#        [0.73622986, 0.26377014],
#        [0.21361209, 0.78638791],
#        [0.79911515, 0.20088485],
#        [0.61813559, 0.38186441],
#        [0.91275537, 0.08724463],
#        [0.20307646, 0.79692354],
#        [0.85988238, 0.14011762],
#        [0.7166821 , 0.2833179 ],
#        [0.49254421, 0.50745579],
#        [0.90658539, 0.09341461],
#        [0.79881758, 0.20118242],
#        [0.7485887 , 0.2514113 ],
#        [0.83459176, 0.16540824],
#        [0.73546193, 0.26453807],
#        [0.47065701, 0.52934299],
#        [0.9148262 , 0.0851738 ],
#        [0.55008826, 0.44991174],
#        [0.82041724, 0.17958276],
#        [0.54660158, 0.45339842],
#        [0.18238133, 0.81761867],
#        [0.58559257, 0.41440743],
#        [0.94697439, 0.05302561],
#        [0.79801574, 0.20198426],
#        [0.40260465, 0.59739535],
#        [0.74381587, 0.25618413],
#        [0.59602209, 0.40397791],
#        [0.98796416, 0.01203584],
#        [0.87515958, 0.12484042],
#        [0.68003907, 0.31996093],
#        [0.76435684, 0.23564316],
#        [0.67504454, 0.32495546],
#        [0.97285714, 0.02714286],
#        [0.5948772 , 0.4051228 ],
#        [0.27166615, 0.72833385],
#        [0.90869833, 0.09130167],
#        [0.56418142, 0.43581858],
#        [0.35038715, 0.64961285],
#        [0.7697661 , 0.2302339 ],
#        [0.13537494, 0.86462506],
#        [0.66509166, 0.33490834],
#        [0.144055  , 0.855945  ],
#        [0.94928887, 0.05071113],
#        [0.17152208, 0.82847792],
#        [0.59257568, 0.40742432],
#        [0.63287964, 0.36712036],
#        [0.40984057, 0.59015943],
#        [0.31199546, 0.68800454],
#        [0.70754489, 0.29245511],
#        [0.52342343, 0.47657657],
#        [0.81970384, 0.18029616],
#        [0.93439084, 0.06560916],
#        [0.27903133, 0.72096867],
#        [0.48551484, 0.51448516],
#        [0.76152559, 0.23847441],
#        [0.53764019, 0.46235981],
#        [0.4782723 , 0.5217277 ],
#        [0.9535774 , 0.0464226 ],
#        [0.92495709, 0.07504291],
#        [0.97625602, 0.02374398],
#        [0.92038966, 0.07961034],
#        [0.86097864, 0.13902136],
#        [0.51731881, 0.48268119],
#        [0.41370951, 0.58629049],
#        [0.88772262, 0.11227738],
#        [0.69169499, 0.30830501],
#        [0.93532172, 0.06467828],
#        [0.69139367, 0.30860633],
#        [0.67617258, 0.32382742],
#        [0.80582195, 0.19417805],
#        [0.56558607, 0.43441393],
#        [0.61542846, 0.38457154],
#        [0.54477269, 0.45522731],
#        [0.92045507, 0.07954493],
#        [0.97556745, 0.02443255],
#        [0.83104739, 0.16895261],
#        [0.63797188, 0.36202812],
#        [0.68229771, 0.31770229],
#        [0.46145839, 0.53854161],
#        [0.58835309, 0.41164691],
#        [0.88933631, 0.11066369],
#        [0.57464344, 0.42535656],
#        [0.94969986, 0.05030014],
#        [0.77953788, 0.22046212],
#        [0.82892444, 0.17107556],
#        [0.49290738, 0.50709262],
#        [0.75470728, 0.24529272],
#        [0.71465181, 0.28534819],
#        [0.70272549, 0.29727451],
#        [0.9156521 , 0.0843479 ],
#        [0.56727788, 0.43272212],
#        [0.05283573, 0.94716427],
#        [0.30847178, 0.69152822],
#        [0.67174392, 0.32825608],
#        [0.67061373, 0.32938627],
#        [0.43673454, 0.56326546],
#        [0.24908244, 0.75091756],
#        [0.47926012, 0.52073988],
#        [0.41354418, 0.58645582],
#        [0.48722051, 0.51277949],
#        [0.65674275, 0.34325725],
#        [0.36518861, 0.63481139],
#        [0.60106872, 0.39893128],
#        [0.85734718, 0.14265282],
#        [0.73428858, 0.26571142],
#        [0.1510498 , 0.8489502 ],
#        [0.21234126, 0.78765874],
#        [0.6767932 , 0.3232068 ],
#        [0.84844176, 0.15155824],
#        [0.8155666 , 0.1844334 ],
#        [0.87877208, 0.12122792],
#        [0.80271555, 0.19728445],
#        [0.90762832, 0.09237168],
#        [0.80095435, 0.19904565],
#        [0.68946544, 0.31053456],
#        [0.98226508, 0.01773492],
#        [0.64453684, 0.35546316],
#        [0.75068709, 0.24931291],
#        [0.49587668, 0.50412332],
#        [0.25577602, 0.74422398],
#        [0.49133793, 0.50866207],
#        [0.04288103, 0.95711897],
#        [0.47189395, 0.52810605],
#        [0.76053478, 0.23946522],
#        [0.2703623 , 0.7296377 ],
#        [0.57532925, 0.42467075],
#        [0.8068469 , 0.1931531 ],
#        [0.93855222, 0.06144778],
#        [0.47432831, 0.52567169],
#        [0.92242757, 0.07757243],
#        [0.81014524, 0.18985476],
#        [0.60137379, 0.39862621],
#        [0.32166155, 0.67833845],
#        [0.16366215, 0.83633785],
#        [0.96406008, 0.03593992],
#        [0.47954734, 0.52045266],
#        [0.74324591, 0.25675409],
#        [0.41263659, 0.58736341],
#        [0.03911842, 0.96088158],
#        [0.94563023, 0.05436977],
#        [0.6328671 , 0.3671329 ],
#        [0.74332798, 0.25667202],
#        [0.80721764, 0.19278236],
#        [0.75313246, 0.24686754],
#        [0.81191228, 0.18808772],
#        [0.66500384, 0.33499616],
#        [0.91591728, 0.08408272],
#        [0.63291151, 0.36708849],
#        [0.84395655, 0.15604345],
#        [0.8610166 , 0.1389834 ],
#        [0.11099564, 0.88900436],
#        [0.74886664, 0.25113336],
#        [0.74489829, 0.25510171],
#        [0.61958871, 0.38041129],
#        [0.9138781 , 0.0861219 ],
#        [0.82555594, 0.17444406],
#        [0.46404896, 0.53595104],
#        [0.92217505, 0.07782495],
#        [0.66009692, 0.33990308],
#        [0.5647455 , 0.4352545 ],
#        [0.79027142, 0.20972858],
#        [0.16151189, 0.83848811],
#        [0.17828457, 0.82171543],
#        [0.78579789, 0.21420211],
#        [0.6678721 , 0.3321279 ],
#        [0.78255775, 0.21744225],
#        [0.28262818, 0.71737182],
#        [0.92535624, 0.07464376],
#        [0.74306852, 0.25693148],
#        [0.54801512, 0.45198488],
#        [0.69798579, 0.30201421],
#        [0.35435348, 0.64564652],
#        [0.63990218, 0.36009782],
#        [0.92039489, 0.07960511],
#        [0.54090245, 0.45909755],
#        [0.91870734, 0.08129266],
#        [0.84949141, 0.15050859],
#        [0.56998976, 0.43001024],
#        [0.14764657, 0.85235343],
#        [0.3833006 , 0.6166994 ],
#        [0.60268892, 0.39731108],
#        [0.50721593, 0.49278407],
#        [0.69174765, 0.30825235],
#        [0.85107733, 0.14892267],
#        [0.80077806, 0.19922194],
#        [0.47804996, 0.52195004],
#        [0.69407142, 0.30592858],
#        [0.42352458, 0.57647542],
#        [0.55208245, 0.44791755],
#        [0.5228449 , 0.4771551 ],
#        [0.87648191, 0.12351809],
#        [0.30083624, 0.69916376],
#        [0.63315559, 0.36684441],
#        [0.53288105, 0.46711895],
#        [0.60643807, 0.39356193],
#        [0.78456873, 0.21543127],
#        [0.89560376, 0.10439624],
#        [0.81106851, 0.18893149],
#        [0.57467956, 0.42532044],
#        [0.27359827, 0.72640173],
#        [0.4946481 , 0.5053519 ],
#        [0.16840575, 0.83159425],
#        [0.86564021, 0.13435979],
#        [0.51944303, 0.48055697],
#        [0.65728199, 0.34271801],
#        [0.77940872, 0.22059128],
#        [0.78170565, 0.21829435]])

# %%
# Померить roc_auc на тесте
lr_predictTest = lr.predict(X_test)
roc_auc_lrTest = roc_auc_score(y_test, lr_predictTest) 
print ( "roc_auc_lr", roc_auc_lrTest )
# Out:
# roc_auc_lr 0.4886411316909428
